# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_excel("/Users/abdelrahmanhesham/MandobakUpdatedData.xlsx")
df
# Out:
#                                                   SKU  اجمالي البيع  \
# 0                 بسكويت اوريو 3ج-28جم -كرتونه * 8علب          1022
# 1            بسكويت اوريو 3قطع 5ج-علبة *12 قطعة   (8)          7864
# 2         بسكويت اوريو 3قطعة شوكولاتة-5ج كرتونة*8 علب           100
# 3                      اوريو فانيليا 10ج-كرتونة*8 علب          6300
# 4               بسكويت بوريو 5ج- 36 جرام كرتونة *8علب         15678
# 5   لبان ترايدنت صغير (توت وفراولة) -20علبة *65 قط...         40575
# 6           لبان ترايدنت صغير (بطيخ) -كرتونة *20 علبة         47987
# 7          لبان تشكليس نعناع اخضر -علبة *65 قطعة (20)          7518
# 8                     لبان كلورتس اخضر اصلى * 65 قطعة         51638
# 9                  لبان كلورتس (ليمون قرفه)-كرتونة*20         15003
# 10          مندولين 10ج 50 جم -علبة *12قطعة * 12 علبة         14528
# 11            مندولين 5ج -علبة *12قطعة 20جم * 24 علبة         31292
# 12                مندولين 3ج -كرتونة *24 قطعة 15 جرام           899
# ...

# %%
df.head()
# Out:
#                                            SKU  اجمالي البيع  عدد العملاء  \
# 0          بسكويت اوريو 3ج-28جم -كرتونه * 8علب          1022           20
# 1     بسكويت اوريو 3قطع 5ج-علبة *12 قطعة   (8)          7864           85
# 2  بسكويت اوريو 3قطعة شوكولاتة-5ج كرتونة*8 علب           100            1
# 3               اوريو فانيليا 10ج-كرتونة*8 علب          6300           43
# 4        بسكويت بوريو 5ج- 36 جرام كرتونة *8علب         15678           96
#
#    عدد الفواتير كمية البيع  Category
# 0            26          4  Biscuits
# 1            91         19  Biscuits
# 2             1      2علبة  Biscuits
# 3            52          8  Biscuits
# 4            99         38  Biscuits

# %%
df.tail()
# Out:
#                                                   SKU  اجمالي البيع  \
# 14                   مورو 7ج -علبة *18 قطعة 17جم (12)          5135
# 15     مشروب هوت شوكلت كادبوري 30 جرام ـ كرتونة*8 علب          2100
# 16  بسكويت كادبوري دبل شوكولاتة 25 جرام 7 ج كرتونة...          1470
# 17  بسكويت كادبوري دبل شوكولاتة 34 جرام 10 ج كرتون...          1125
# 18       بودر تانج طعم ( البرتقال ) -5ج-كرتونة*12علبة          1870
#
#     عدد العملاء  عدد الفواتير كمية البيع           Category
# 14           12            16          4          Chocolate
# 15            4             7          2              Cocoa
# 16            7            10          1           Biscuits
# 17            6             9     15علبة           Biscuits
# 18            5             7          1  Powdered Beverage
